# %%
from IPython.display import HTML

HTML('''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>remedicaAI - Medicinal Waste Analysis</title>
    <link href="https://fonts.googleapis.com/css2?family=PT+Sans:wght@400;700&display=swap" rel="stylesheet">
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
    <style>
        :root {
            --primary-color: #388E3C;
            --background-color: #F5F5DC;
            --accent-color: #A1887F;
            --text-color: #333;
            --light-text: #fff;
            --card-bg: #fff;
            --shadow: 0 4px 12px rgba(0, 0, 0, 0.1);
        }

        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }

        body {
            font-family: 'PT Sans', sans-serif;
            background-color: var(--background-color);
            color: var(--text-color);
            line-height: 1.6;
        }

        .container {
            max-width: 1200px;
            margin: 0 auto;
            padding: 0 20px;
        }

        header {
            background-color: var(--primary-color);
            color: var(--light-text);
            padding: 20px 0;
            box-shadow: var(--shadow);
        }

        .header-content {
            display: flex;
            justify-content: space-between;
            align-items: center;
        }

        .logo {
            display: flex;
            align-items: center;
            gap: 15px;
        }

        .logo i {
            font-size: 2rem;
        }

        .logo h1 {
            font-size: 1.8rem;
            font-weight: 700;
        }

        nav ul {
            display: flex;
            list-style: none;
            gap: 25px;
        }

        nav a {
            color: var(--light-text);
            text-decoration: none;
            font-weight: 700;
            transition: opacity 0.3s;
        }

        nav a:hover {
            opacity: 0.8;
        }

        .hero {
            padding: 60px 0;
            text-align: center;
            background: linear-gradient(rgba(56, 142, 60, 0.9), rgba(56, 142, 60, 0.7)), url('data:image/svg+xml;utf8,<svg xmlns="http://www.w3.org/2000/svg" width="100" height="100" viewBox="0 0 100 100"><rect width="100" height="100" fill="%23388E3C"/><path d="M0 0L100 100M100 0L0 100" stroke="%23307A34" stroke-width="2"/></svg>');
            color: var(--light-text);
        }

        .hero h2 {
            font-size: 2.5rem;
            margin-bottom: 20px;
        }

        .hero p {
            font-size: 1.2rem;
            max-width: 700px;
            margin: 0 auto 30px;
        }

        .input-section {
            background-color: var(--card-bg);
            padding: 40px;
            border-radius: 10px;
            box-shadow: var(--shadow);
            margin-top: -50px;
            position: relative;
            z-index: 10;
        }

        .input-container {
            display: flex;
            flex-direction: column;
            gap: 30px;
        }

        .input-method {
            display: flex;
            gap: 20px;
            margin-bottom: 20px;
        }

        .method-btn {
            flex: 1;
            padding: 15px;
            background-color: var(--card-bg);
            border: 2px solid var(--primary-color);
            border-radius: 8px;
            font-size: 1rem;
            font-weight: 700;
            color: var(--primary-color);
            cursor: pointer;
            transition: all 0.3s;
            display: flex;
            align-items: center;
            justify-content: center;
            gap: 10px;
        }

        .method-btn.active {
            background-color: var(--primary-color);
            color: var(--light-text);
        }

        .method-btn:hover:not(.active) {
            background-color: rgba(56, 142, 60, 0.1);
        }

        .input-area {
            display: none;
        }

        .input-area.active {
            display: block;
            animation: fadeIn 0.5s ease;
        }

        @keyframes fadeIn {
            from { opacity: 0; transform: translateY(10px); }
            to { opacity: 1; transform: translateY(0); }
        }

        .upload-area {
            border: 2px dashed var(--accent-color);
            border-radius: 8px;
            padding: 40px 20px;
            text-align: center;
            cursor: pointer;
            transition: all 0.3s;
        }

        .upload-area:hover {
            background-color: rgba(161, 136, 127, 0.05);
        }

        .upload-area i {
            font-size: 3rem;
            color: var(--accent-color);
            margin-bottom: 15px;
        }

        .text-input {
            width: 100%;
            padding: 15px;
            border: 2px solid var(--accent-color);
            border-radius: 8px;
            font-size: 1rem;
            font-family: 'PT Sans', sans-serif;
        }

        .analyze-btn {
            background-color: var(--primary-color);
            color: var(--light-text);
            border: none;
            padding: 15px 30px;
            border-radius: 8px;
            font-size: 1.1rem;
            font-weight: 700;
            cursor: pointer;
            transition: all 0.3s;
            display: block;
            margin: 20px auto 0;
            width: 200px;
        }

        .analyze-btn:hover {
            background-color: #2E7D32;
            transform: translateY(-2px);
            box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
        }

        .loading {
            display: none;
            text-align: center;
            padding: 30px;
        }

        .loading.active {
            display: block;
            animation: fadeIn 0.5s ease;
        }

        .spinner {
            border: 5px solid rgba(56, 142, 60, 0.2);
            border-radius: 50%;
            border-top: 5px solid var(--primary-color);
            width: 50px;
            height: 50px;
            animation: spin 1s linear infinite;
            margin: 0 auto 20px;
        }

        @keyframes spin {
            0% { transform: rotate(0deg); }
            100% { transform: rotate(360deg); }
        }

        .results {
            display: none;
            margin-top: 40px;
            animation: fadeIn 0.8s ease;
        }

        .results.active {
            display: block;
        }

        .results-header {
            text-align: center;
            margin-bottom: 30px;
        }

        .results-header h2 {
            color: var(--primary-color);
            font-size: 2rem;
            margin-bottom: 10px;
        }

        .compound-card {
            background-color: var(--card-bg);
            border-radius: 10px;
            box-shadow: var(--shadow);
            padding: 25px;
            margin-bottom: 25px;
            transition: transform 0.3s;
        }

        .compound-card:hover {
            transform: translateY(-5px);
        }

        .compound-header {
            display: flex;
            justify-content: space-between;
            align-items: center;
            margin-bottom: 20px;
            padding-bottom: 15px;
            border-bottom: 1px solid rgba(0, 0, 0, 0.1);
        }

        .compound-name {
            font-size: 1.5rem;
            font-weight: 700;
            color: var(--primary-color);
        }

        .compound-stats {
            display: flex;
            gap: 15px;
        }

        .stat {
            display: flex;
            flex-direction: column;
            align-items: center;
            gap: 5px;
        }

        .stat-value {
            font-weight: 700;
            font-size: 1.2rem;
        }

        .stat-label {
            font-size: 0.8rem;
            color: var(--accent-color);
        }

        .compound-details {
            display: grid;
            grid-template-columns: repeat(auto-fit, minmax(250px, 1fr));
            gap: 20px;
        }

        .detail-section {
            margin-bottom: 20px;
        }

        .detail-section h4 {
            color: var(--accent-color);
            margin-bottom: 10px;
            font-size: 1.1rem;
        }

        .detail-section ul {
            list-style-type: none;
        }

        .detail-section li {
            margin-bottom: 8px;
            padding-left: 20px;
            position: relative;
        }

        .detail-section li:before {
            content: "•";
            color: var(--primary-color);
            position: absolute;
            left: 0;
        }

        .benefits li:before {
            color: #4CAF50;
        }

        .side-effects li:before {
            color: #F44336;
        }

        .toxicity-level {
            display: inline-block;
            padding: 5px 10px;
            border-radius: 20px;
            font-size: 0.8rem;
            font-weight: 700;
        }

        .toxicity-low {
            background-color: #E8F5E9;
            color: #2E7D32;
        }

        .toxicity-medium {
            background-color: #FFF3E0;
            color: #EF6C00;
        }

        .toxicity-high {
            background-color: #FFEBEE;
            color: #C62828;
        }

        footer {
            background-color: var(--primary-color);
            color: var(--light-text);
            padding: 40px 0;
            margin-top: 60px;
        }

        .footer-content {
            display: flex;
            justify-content: space-between;
            flex-wrap: wrap;
            gap: 40px;
        }

        .footer-section {
            flex: 1;
            min-width: 250px;
        }

        .footer-section h3 {
            margin-bottom: 20px;
            font-size: 1.3rem;
        }

        .footer-section p, .footer-section a {
            color: rgba(255, 255, 255, 0.8);
            margin-bottom: 10px;
            display: block;
            text-decoration: none;
        }

        .footer-section a:hover {
            text-decoration: underline;
        }

        .copyright {
            text-align: center;
            margin-top: 40px;
            padding-top: 20px;
            border-top: 1px solid rgba(255, 255, 255, 0.2);
        }

        @media (max-width: 768px) {
            .header-content {
                flex-direction: column;
                gap: 15px;
            }

            .input-method {
                flex-direction: column;
            }

            .hero h2 {
                font-size: 2rem;
            }

            .compound-header {
                flex-direction: column;
                align-items: flex-start;
                gap: 15px;
            }

            .compound-stats {
                width: 100%;
                justify-content: space-between;
            }
        }
    </style>
</head>
<body>
    <header>
        <div class="container">
            <div class="header-content">
                <div class="logo">
                    <i class="fas fa-leaf"></i>
                    <h1>remedicaAI</h1>
                </div>
                <nav>
                    <ul>
                        <li><a href="#"><i class="fas fa-home"></i> Home</a></li>
                        <li><a href="#"><i class="fas fa-info-circle"></i> About</a></li>
                        <li><a href="#"><i class="fas fa-book"></i> Resources</a></li>
                        <li><a href="#"><i class="fas fa-envelope"></i> Contact</a></li>
                    </ul>
                </nav>
            </div>
        </div>
    </header>

    <section class="hero">
        <div class="container">
            <h2>Discover Medicinal Compounds in Waste Materials</h2>
            <p>Upload an image or enter the name of a waste material to analyze its medicinal compounds, potential benefits, side effects, and applications.</p>
        </div>
    </section>

    <section class="container">
        <div class="input-section">
            <div class="input-container">
                <div class="input-method">
                    <button class="method-btn active" data-method="image">
                        <i class="fas fa-camera"></i> Upload Image
                    </button>
                    <button class="method-btn" data-method="text">
                        <i class="fas fa-keyboard"></i> Text Input
                    </button>
                </div>

                <div class="input-area active" id="image-input">
                    <div class="upload-area" id="upload-area">
                        <i class="fas fa-cloud-upload-alt"></i>
                        <h3>Upload Image of Waste Material</h3>
                        <p>Click to browse or drag and drop an image file</p>
                        <input type="file" id="file-input" accept="image/*" style="display: none;">
                    </div>
                </div>

                <div class="input-area" id="text-input">
                    <input type="text" class="text-input" id="text-field" placeholder="Enter the name of a waste material (e.g., banana peels, coffee grounds, orange rinds)">
                </div>

                <button class="analyze-btn" id="analyze-button">
                    <i class="fas fa-search"></i> Analyze Material
                </button>
            </div>
        </div>

        <div class="loading" id="loading-indicator">
            <div class="spinner"></div>
            <h3>Analyzing Material...</h3>
            <p>Our AI is identifying medicinal compounds in your waste material</p>
        </div>

        <div class="results" id="results-section">
            <div class="results-header">
                <h2>Analysis Results</h2>
                <p>Medicinal compounds identified in <span id="material-name">banana peels</span></p>
            </div>

            <div class="compound-card">
                <div class="compound-header">
                    <div class="compound-name">Allantoin</div>
                    <div class="compound-stats">
                        <div class="stat">
                            <div class="stat-value">85%</div>
                            <div class="stat-label">Confidence</div>
                        </div>
                        <div class="stat">
                            <div class="stat-value toxicity-level toxicity-low">Low</div>
                            <div class="stat-label">Toxicity</div>
                        </div>
                    </div>
                </div>
                <div class="compound-details">
                    <div class="detail-section">
                        <h4>Potential Benefits</h4>
                        <ul class="benefits">
                            <li>Promotes wound healing and tissue regeneration</li>
                            <li>Has anti-inflammatory properties</li>
                            <li>Moisturizes and soothes skin</li>
                            <li>Stimulates cell proliferation</li>
                        </ul>
                    </div>
                    <div class="detail-section">
                        <h4>Common Applications</h4>
                        <ul>
                            <li>Topical creams for skin conditions</li>
                            <li>Wound healing ointments</li>
                            <li>Anti-aging skincare products</li>
                            <li>Treatment of psoriasis and eczema</li>
                        </ul>
                    </div>
                    <div class="detail-section">
                        <h4>Side Effects</h4>
                        <ul class="side-effects">
                            <li>Rare skin irritation in sensitive individuals</li>
                            <li>Mild redness with excessive use</li>
                        </ul>
                    </div>
                </div>
            </div>

            <div class="compound-card">
                <div class="compound-header">
                    <div class="compound-name">Potassium</div>
                    <div class="compound-stats">
                        <div class="stat">
                            <div class="stat-value">92%</div>
                            <div class="stat-label">Confidence</div>
                        </div>
                        <div class="stat">
                            <div class="stat-value toxicity-level toxicity-low">Low</div>
                            <div class="stat-label">Toxicity</div>
                        </div>
                    </div>
                </div>
                <div class="compound-details">
                    <div class="detail-section">
                        <h4>Potential Benefits</h4>
                        <ul class="benefits">
                            <li>Regulates fluid balance in the body</li>
                            <li>Supports nerve function and muscle contractions</li>
                            <li>Helps maintain normal blood pressure</li>
                            <li>Essential for cardiovascular health</li>
                        </ul>
                    </div>
                    <div class="detail-section">
                        <h4>Common Applications</h4>
                        <ul>
                            <li>Dietary supplements</li>
                            <li>Treatment of potassium deficiency</li>
                            <li>Cardiovascular health formulations</li>
                            <li>Sports nutrition products</li>
                        </ul>
                    </div>
                    <div class="detail-section">
                        <h4>Side Effects</h4>
                        <ul class="side-effects">
                            <li>Nausea or stomach discomfort in high doses</li>
                            <li>Hyperkalemia with excessive supplementation</li>
                        </ul>
                    </div>
                </div>
            </div>

            <div class="compound-card">
                <div class="compound-header">
                    <div class="compound-name">Tannins</div>
                    <div class="compound-stats">
                        <div class="stat">
                            <div class="stat-value">78%</div>
                            <div class="stat-label">Confidence</div>
                        </div>
                        <div class="stat">
                            <div class="stat-value toxicity-level toxicity-medium">Medium</div>
                            <div class="stat-label">Toxicity</div>
                        </div>
                    </div>
                </div>
                <div class="compound-details">
                    <div class="detail-section">
                        <h4>Potential Benefits</h4>
                        <ul class="benefits">
                            <li>Antioxidant properties</li>
                            <li>Anti-inflammatory effects</li>
                            <li>Antimicrobial activity</li>
                            <li>Astringent properties for skin</li>
                        </ul>
                    </div>
                    <div class="detail-section">
                        <h4>Common Applications</h4>
                        <ul>
                            <li>Natural preservatives in cosmetics</li>
                            <li>Treatment of diarrhea</li>
                            <li>Skin toners and astringents</li>
                            <li>Anti-aging skincare formulations</li>
                        </ul>
                    </div>
                    <div class="detail-section">
                        <h4>Side Effects</h4>
                        <ul class="side-effects">
                            <li>Can interfere with iron absorption</li>
                            <li>May cause constipation in high dose</li>
                            <li>Gastric irritation in sensitive individuals</li>
                        </ul>
                    </div>
                </div>
            </div>

        </div>
    </section>

    <footer>
        <div class="container">
            <div class="footer-content">
                <div class="footer-section">
                    <h3>remedicaAI</h3>
                    <p>Leveraging AI for sustainable medicinal waste analysis.</p>
                    <p><i class="fas fa-map-marker-alt"></i> 123 Eco-Lane, Green City, GC 12345</p>
                    <p><i class="fas fa-envelope"></i> info@remedicaai.com</p>
                    <p><i class="fas fa-phone"></i> +1 (555) 123-4567</p>
                </div>
                <div class="footer-section">
                    <h3>Quick Links</h3>
                    <ul>
                        <li><a href="#">Home</a></li>
                        <li><a href="#">About Us</a></li>
                        <li><a href="#">Services</a></li>
                        <li><a href="#">Privacy Policy</a></li>
                        <li><a href="#">Terms of Service</a></li>
                    </ul>
                </div>
                <div class="footer-section">
                    <h3>Follow Us</h3>
                    <ul>
                        <li><a href="#"><i class="fab fa-facebook"></i> Facebook</a></li>
                        <li><a href="#"><i class="fab fa-twitter"></i> Twitter</a></li>
                        <li><a href="#"><i class="fab fa-linkedin"></i> LinkedIn</a></li>
                        <li><a href="#"><i class="fab fa-instagram"></i> Instagram</a></li>
                    </ul>
                </div>
            </div>
            <div class="copyright">
                <p>&copy; 2023 remedicaAI. All rights reserved.</p>
            </div>
        </div>
    </footer>

    <script>
        document.addEventListener('DOMContentLoaded', () => {
            const methodBtns = document.querySelectorAll('.method-btn');
            const inputAreas = document.querySelectorAll('.input-area');
            const uploadArea = document.getElementById('upload-area');
            const fileInput = document.getElementById('file-input');
            const analyzeButton = document.getElementById('analyze-button');
            const loadingIndicator = document.getElementById('loading-indicator');
            const resultsSection = document.getElementById('results-section');
            const materialNameSpan = document.getElementById('material-name');
            const textField = document.getElementById('text-field');

            methodBtns.forEach(btn => {
                btn.addEventListener('click', () => {
                    methodBtns.forEach(b => b.classList.remove('active'));
                    btn.classList.add('active');

                    inputAreas.forEach(area => area.classList.remove('active'));
                    document.getElementById(`${btn.dataset.method}-input`).classList.add('active');
                });
            });

            uploadArea.addEventListener('click', () => {
                fileInput.click();
            });

            uploadArea.addEventListener('dragover', (e) => {
                e.preventDefault();
                uploadArea.style.borderColor = `var(--primary-color)`;
            });

            uploadArea.addEventListener('dragleave', (e) => {
                e.preventDefault();
                uploadArea.style.borderColor = `var(--accent-color)`;
            });

            uploadArea.addEventListener('drop', (e) => {
                e.preventDefault();
                uploadArea.style.borderColor = `var(--accent-color)`;
                const files = e.dataTransfer.files;
                if (files.length > 0) {
                    handleFiles(files);
                }
            });

            fileInput.addEventListener('change', (e) => {
                handleFiles(e.target.files);
            });

            function handleFiles(files) {
                if (files.length > 0) {
                    const file = files[0];
                    // In a real application, you would upload the file to a server
                    console.log('File selected:', file.name);
                    // Optionally, display a preview or file name
                    uploadArea.querySelector('h3').textContent = `File: ${file.name}`;
                    uploadArea.querySelector('p').textContent = 'Ready for analysis';
                }
            }

            analyzeButton.addEventListener('click', () => {
                loadingIndicator.classList.add('active');
                resultsSection.classList.remove('active');
                // Simulate API call
                setTimeout(() => {
                    loadingIndicator.classList.remove('active');
                    resultsSection.classList.add('active');

                    let material = '';
                    if (document.getElementById('image-input').classList.contains('active')) {
                        material = fileInput.files.length > 0 ? fileInput.files[0].name.split('.')[0] : 'unknown image';
                    } else {
                        material = textField.value || 'unspecified material';
                    }
                    materialNameSpan.textContent = material;

                }, 3000); // 3 seconds delay
            });
        });
    </script>
</body>
</html>
''')
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>remedicaAI - Medicinal Waste Analysis</title>
#     <link href="https://fonts.googleapis.com/css2?family=PT+Sans:wght@400;700&display=swap" rel="stylesheet">
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
#     <style>
#         :root {
#             --primary-color: #388E3C;
#             --background-color: #F5F5DC;
#             --accent-color: #A1887F;
#             --text-color: #333;
#             --light-text: #fff;
#             --card-bg: #fff;
#             --shadow: 0 4px 12px rgba(0, 0, 0, 0.1);
#         }
#
#         * {
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         }
#
#         body {
#             font-family: 'PT Sans', sans-serif;
#             background-color: var(--background-color);
# ...
